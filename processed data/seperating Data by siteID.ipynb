# %% [markdown]
# # Separating Data by SiteID

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
# %matplotlib inline
from datetime import datetime

# %%
df=pd.read_csv("data/processed_data_all.csv")

# %%
df["siteID"].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
site1_Data=df[df["siteID"]==1]
site2_Data=df[df["siteID"]==2]

# %%
site1_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35041 entries, 8582 to 66422
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               35041 non-null  int64
#  1   id                       35041 non-null  object
#  2   connectionTime           35041 non-null  object
#  3   disconnectTime           35041 non-null  object
#  4   doneChargingTime         35041 non-null  object
#  5   kWhDelivered             35041 non-null  float64
#  6   sessionID                35041 non-null  object
#  7   siteID                   35041 non-null  int64
#  8   spaceID                  35041 non-null  object
#  9   stationID                35041 non-null  object
#  10  timezone                 35041 non-null  object
#  11  WhPerMile                35041 non-null  object
#  12  kWhRequested             35041 non-null  object
#  13  milesRequested           35041 non-null  object
#  14  minutesAvailable         35041 non-null  object
#  15  modifiedAt               32814 non-null  object
#  16  paymentRequired          35041 non-null  object
#  17  requestedDeparture       32814 non-null  object
#  18  userID                   35041 non-null  object
#  19  timestamp                35041 non-null  object
#  20  temperature              35041 non-null  float64
#  21  cloud_cover              35041 non-null  float64
#  22  cloud_cover_description  35041 non-null  object
#  23  pressure                 35041 non-null  float64
#  24  windspeed                35041 non-null  float64
#  25  precipitation            35041 non-null  float64
# dtypes: float64(6), int64(2), object(18)
# memory usage: 7.2+ MB

# %%
site2_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31382 entries, 0 to 66421
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               31382 non-null  int64
#  1   id                       31382 non-null  object
#  2   connectionTime           31382 non-null  object
#  3   disconnectTime           31382 non-null  object
#  4   doneChargingTime         31382 non-null  object
#  5   kWhDelivered             31382 non-null  float64
#  6   sessionID                31382 non-null  object
#  7   siteID                   31382 non-null  int64
#  8   spaceID                  31382 non-null  object
#  9   stationID                31382 non-null  object
#  10  timezone                 31382 non-null  object
#  11  WhPerMile                31382 non-null  object
#  12  kWhRequested             31382 non-null  object
#  13  milesRequested           31382 non-null  object
#  14  minutesAvailable         31382 non-null  object
#  15  modifiedAt               16367 non-null  object
#  16  paymentRequired          31382 non-null  object
#  17  requestedDeparture       16367 non-null  object
#  18  userID                   31382 non-null  object
#  19  timestamp                31382 non-null  object
#  20  temperature              31382 non-null  float64
#  21  cloud_cover              31382 non-null  float64
#  22  cloud_cover_description  31382 non-null  object
#  23  pressure                 31382 non-null  float64
#  24  windspeed                31382 non-null  float64
#  25  precipitation            31382 non-null  float64
# dtypes: float64(6), int64(2), object(18)
# memory usage: 6.5+ MB

# %%
site1_Data.to_csv('data/site1_Data.csv', index=False)
site2_Data.to_csv('data/site2_Data.csv', index=False)
